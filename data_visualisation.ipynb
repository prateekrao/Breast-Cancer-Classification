# %% [markdown]
# <a href="https://colab.research.google.com/github/nevasini/Breast-Cancer-Detection/blob/main/data_visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from glob import glob
import cv2
import sklearn
imagePatches = glob("../Breast-Cancer-Classification/split-data/**/*.png", recursive=True)
for filename in imagePatches[0:3]:
    print(filename)
# Out:
# ../Breast-Cancer-Classification/split-data/valid/one/12749_idx5_x3201_y1351_class1.png
# ../Breast-Cancer-Classification/split-data/valid/one/9226_idx5_x701_y2101_class1.png
# ../Breast-Cancer-Classification/split-data/valid/one/15632_idx5_x1601_y1851_class1.png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### Showing a random image

# %%
image_name = imagePatches[83]
def plotImage(image_location):
    image = cv2.imread(image_name)
    image = cv2.resize(image, (50,50))

    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)); plt.axis('off')
    return 
plotImage(image_name)

# %%
from glob import glob
imagePatches=glob("/content/dataset/master-dataset/**/*.png")

# %% [markdown]
# ### Showing a bunch of random images

# %%
bunchOfImages = imagePatches
i_ = 0
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.subplots_adjust(wspace=0, hspace=0)
for l in bunchOfImages[:10]:
    im = cv2.imread(l)
    im = cv2.resize(im, (50, 50)) 
    plt.subplot(5, 5, i_+1) #.set_title(l)
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB)); plt.axis('off')
    i_ += 1

# %%
zeroPatch = glob('../Breast-Cancer-Classification/split-data/**/zero/*class0.png')
onePatch = glob('../Breast-Cancer-Classification/split-data/**/one/*class1.png')

# %%
print("IDC(-)\n\n",zeroPatch[0:5],'\n')
print("IDC(+)\n\n",onePatch[0:5])
# Out:
# IDC(-)
#
#  ['../Breast-Cancer-Classification/split-data/valid/zero/12749_idx5_x1451_y701_class0.png', '../Breast-Cancer-Classification/split-data/valid/zero/13693_idx5_x1901_y2851_class0.png', '../Breast-Cancer-Classification/split-data/valid/zero/10301_idx5_x1551_y1701_class0.png', '../Breast-Cancer-Classification/split-data/valid/zero/10293_idx5_x551_y1701_class0.png', '../Breast-Cancer-Classification/split-data/valid/zero/9076_idx5_x2851_y201_class0.png']
#
# IDC(+)
#
#  ['../Breast-Cancer-Classification/split-data/valid/one/12749_idx5_x3201_y1351_class1.png', '../Breast-Cancer-Classification/split-data/valid/one/9226_idx5_x701_y2101_class1.png', '../Breast-Cancer-Classification/split-data/valid/one/15632_idx5_x1601_y1851_class1.png', '../Breast-Cancer-Classification/split-data/valid/one/15903_idx5_x1451_y751_class1.png', '../Breast-Cancer-Classification/split-data/valid/one/9023_idx5_x1351_y2001_class1.png']

# %%
def plotTwo(zeros): 
    """
    Plot a bunch of numpy arrays sorted by label
    """
    for row in range(3):
        plt.figure(figsize=(20, 10))
        for col in range(3):
            plt.subplot(1,8,col+1)
            plt.title('IDC (-)')
            plt.imshow(a[0+row+col])
            plt.axis('off')       
            plt.subplot(1,8,col+4)
            plt.title('IDC (+)')
            plt.imshow(b[0+row+col])
            plt.axis('off')
plotTwo(imgs0, imgs1)

# %%
zeros = zeroPatch
i_ = 0
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.subplots_adjust(wspace=0, hspace=0)
for l in zeros[:5]:
    im = cv2.imread(l)
    im = cv2.resize(im, (50, 50)) 
    plt.subplot(5, 5, i_+1) 
    plt.title('IDC -ve')
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB)); plt.axis('off')
    i_ += 1

# %%
ones = onePatch
i_ = 0
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.subplots_adjust(wspace=0, hspace=0)
for l in ones[:5]:
    im = cv2.imread(l)
    im = cv2.resize(im, (50, 50)) 
    plt.subplot(5, 5, i_+1) 
    plt.title('IDC +ve')
    plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB)); plt.axis('off')
    i_ += 1

# %%
numbers = [len(zeros), len(ones)]

# %%
plt.pie(numbers, labels=['zero-', 'one+'], radius=1, labeldistance=0.5)
plt.axis('off')
# Out:
# (-1.25, 1.25, -1.25, 1.25)
